# %%
from PIL import Image
import os

def resize_and_rotate_images(directory, max_size=1000, rotation_angle=-90):
    # Loop through all files in the directory
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        # Check if the file is an image
        if os.path.isfile(filepath) and filename.lower().startswith('gambar '):
            with Image.open(filepath) as img:
                # Rotate the image
                rotated_img = img.rotate(rotation_angle, expand=True)  # Expand to adjust the canvas size
                width, height = rotated_img.size
                # Check if width or height exceeds max_size
                if width > max_size or height > max_size:
                    # Calculate the new size maintaining the aspect ratio
                    scaling_factor = max_size / max(width, height)
                    new_width = int(width * scaling_factor)
                    new_height = int(height * scaling_factor)
                    # Resize the image
                    resized_img = rotated_img.resize((new_width, new_height), Image.LANCZOS)
                    # Save the resized and rotated image
                    resized_img.save(filepath)
                    print(f"Processed {filename}: Rotated {rotation_angle}° and resized {width}x{height} -> {new_width}x{new_height}")
                else:
                    # Save the rotated image without resizing if size is within bounds
                    rotated_img.save(filepath)
                    print(f"Processed {filename}: Rotated {rotation_angle}° but not resized (size {width}x{height} within bounds).")

# Directory containing images
images_directory = r"C:\Users\pc\Desktop\obstacles dataset\train\stairs"
resize_and_rotate_images(images_directory)
# Out:
# Processed gambar (11).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (12).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (122).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (123).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (124).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (125).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (126).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (13).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (136).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (137).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (138).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (139).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (14).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (15).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (16).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (162).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (163).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (164).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (165).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (166).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (17).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (18).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (180).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (181).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (182).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (183).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (184).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (185).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (186).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (187).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (188).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (189).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (19).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (20).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (210).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (211).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (212).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (213).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (214).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (215).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (216).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (217).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (218).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (219).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (220).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (242).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (243).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (244).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (245).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (246).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (247).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (248).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (249).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (250).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (251).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (252).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (263).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (264).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (265).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (266).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (267).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (268).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (269).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (270).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (271).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (272).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (273).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (274).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (275).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (276).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (277).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (278).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (477).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (478).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (479).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (480).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (481).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (482).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (483).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (484).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (485).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (486).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (487).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (489).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (490).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (491).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (492).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (493).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (494).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (495).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (509).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (510).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (511).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (512).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (513).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (514).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (515).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (516).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (603).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (604).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (605).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (606).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (607).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (608).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (609).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (610).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (611).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (639).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (640).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (641).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (678).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (679).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (680).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (681).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (740).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (741).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (742).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (743).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (744).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (758).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (759).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (760).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (761).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (762).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (834).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (835).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (836).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (837).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (88).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (89).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
# Processed gambar (90).jpg: Rotated -90° and resized 3060x4080 -> 750x1000
